# %% [markdown]
# <a href="https://colab.research.google.com/github/singithi03/Data-Analytics_s5214680/blob/Assignment_s5214680/7130ICT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/data.csv")
df.head(10)
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
# 5  37404307  Business Banking Contact Centre Specialist, Ni...
# 6  37404355               Casual Café All-rounder in Semaphore
# 7  37404350           Casual Café All-rounder in Woolloongabba
# 8  37404301                                       Telemarketer
# 9  37404286                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318477 entries, 0 to 318476
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 318477 non-null  object
#  1   Title              318477 non-null  object
#  2   Company            306473 non-null  object
#  3   Date               318477 non-null  object
#  4   Location           197229 non-null  object
#  5   Area               122658 non-null  object
#  6   Classification     197229 non-null  object
#  7   SubClassification  197229 non-null  object
#  8   Requirement        318470 non-null  object
#  9   FullDescription    302302 non-null  object
#  10  LowestSalary       318477 non-null  int64
#  11  HighestSalary      318477 non-null  int64
#  12  JobType            302379 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 31.6+ MB

# %% [markdown]
# # **Part 1 - Data Pre-processing and Interpretation**

# %%
df = pd.read_csv('/content/drive/MyDrive/data.csv')
print("The Dataset consists of: ", df.shape[0], " rows and ", df.shape[1], " columuns")
df.head(10)
# Out:
# The Dataset consists of:  318477  rows and  13  columuns
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
# 5  37404307  Business Banking Contact Centre Specialist, Ni...
# 6  37404355               Casual Café All-rounder in Semaphore
# 7  37404350           Casual Café All-rounder in Woolloongabba
# 8  37404301                                       Telemarketer
# 9  37404286                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
df.sort_values(['Date'])
dates_count = df['Date'].value_counts()
dates_count
# Out:
# 2018-10-17T00:00:00.000Z    13059
# 2018-12-14T00:00:00.000Z    11505
# 2019-01-22T00:00:00.000Z     9544
# 2019-01-10T00:00:00.000Z     8736
# 2018-10-31T00:00:00.000Z     8641
#                             ...
# 2019-03-03T00:00:00.000Z        3
# 2018-11-14T00:00:00.000Z        2
# 2019-01-25T00:00:00.000Z        2
# 2019-03-10T00:00:00.000Z        2
# 2019-03-09T00:00:00.000Z        1
# Name: Date, Length: 163, dtype: int64

# %%
dates = df.sort_values('Date')['Date'].dropna().unique()
start_date = dates[0]
end_date = dates[len(dates)-1]
end_date
# Out:
# '2019-03-13T00:00:00.000Z'

# %%
ids = df['Id'].nunique()
titles = df['Title'].nunique()
companies = df['Company'].nunique()
dates = df['Date'].nunique()
locations = df['Location'].nunique()
area = df['Area'].nunique()
classes = df['Classification'].nunique()
subclasses = df['SubClassification'].nunique()
requirements = df['Requirement'].nunique()
description = df['FullDescription'].nunique()
lowest_salary = df['LowestSalary'].nunique()
highest_salary = df['HighestSalary'].nunique()
job_type = df['JobType'].nunique()

# %%
print('Ids',ids)
print('Titles',titles)
print('Companies',companies)
print('Dates',dates)
print('Locations',locations)
print('Area',area)
print('Classes',classes)
print('Subclasses',subclasses)
print('Requirements',requirements)
print('Descriptions',description)
print('Lowest Salary',lowest_salary)
print('Highest Salary', highest_salary)
print('Job Types',job_type)
# Out:
# Ids 318477
# Titles 168065
# Companies 40628
# Dates 163
# Locations 65
# Area 19
# Classes 30
# Subclasses 338
# Requirements 234287
# Descriptions 250901
# Lowest Salary 11
# Highest Salary 11
# Job Types 4

# %%
len(dates_count)
# Out:
# 163

# %%
df['Location'].value_counts()
# Out:
# Sydney                                  60765
# Melbourne                               46690
# Brisbane                                21466
# Perth                                   13198
# Adelaide                                 6653
#                                         ...
# Yorke Peninsula & Clare Valley             96
# Tumut, Snowy & Monaro                      86
# Somerset & Lockyer                         65
# Fleurieu Peninsula & Kangaroo Island       64
# Central & South East TAS                   57
# Name: Location, Length: 65, dtype: int64

# %%
import pandas as pd
# tab = pd.DataFrame()
tab = df['Classification'].value_counts()
# column = ['Job Sectors', 'Total_Job_Postings']
# tab = pd.DataFrame(tab, columns=column)
tab
# Out:
# Information & Communication Technology    22796
# Trades & Services                         17976
# Healthcare & Medical                      17085
# Hospitality & Tourism                     15523
# Manufacturing, Transport & Logistics      12376
# Administration & Office Support           10020
# Accounting                                 9368
# Education & Training                       9280
# Construction                               8372
# Sales                                      8119
# Retail & Consumer Products                 8041
# Government & Defence                       7443
# Engineering                                6458
# Mining, Resources & Energy                 6288
# Banking & Financial Services               4633
# Community Services & Development           4485
# Legal                                      4237
# Human Resources & Recruitment              4144
# Call Centre & Customer Service             3971
# Marketing & Communications                 3968
# ...

# %%
job_sub_counts = df[df['Classification'] == 'Information & Communication Technology']
nnf = job_sub_counts['SubClassification'].value_counts()
nnf
# Out:
# Developers/Programmers                   4211
# Business/Systems Analysts                2986
# Programme & Project Management           2413
# Architects                               1548
# Engineering - Software                   1437
# Help Desk & IT Support                   1374
# Networks & Systems Administration        1194
# Consultants                              1149
# Other                                     997
# Testing & Quality Assurance               831
# Security                                  774
# Management                                746
# Engineering - Network                     552
# Database Development & Administration     551
# Web Development & Production              452
# Sales - Pre & Post                        449
# Product Management & Development          376
# Telecommunications                        357
# Team Leaders                              173
# Engineering - Hardware                    116
# ...

# %%
nnf.size
# Out:
# 22

# %%
job_sub_counts = df['LowestSalary']
job_sub_counts = job_sub_counts.value_counts()
job_sub_counts
# Out:
# 0      62639
# 40     34436
# 70     28712
# 60     28499
# 100    27673
# 50     27027
# 150    25841
# 120    24514
# 80     24249
# 30     23476
# 200    11411
# Name: LowestSalary, dtype: int64

# %%
job_sub_counts1 = df['HighestSalary']
job_sub_counts1 = job_sub_counts1.value_counts()
job_sub_counts1
# Out:
# 30     62639
# 50     34436
# 80     28712
# 70     28499
# 120    27673
# 60     27027
# 200    25841
# 150    24514
# 100    24249
# 40     23476
# 999    11411
# Name: HighestSalary, dtype: int64

# %%
job = df['JobType']
job = job.value_counts()
job
# Out:
# Full Time          201225
# Contract/Temp       53906
# Casual/Vacation     25355
# Part Time           21893
# Name: JobType, dtype: int64

# %% [markdown]
# **2. Normalize & Clean data**

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd4

# df = pd.read_csv("/content/drive/MyDrive/data.csv") # Jobmarket dataset.
df['Average_Salary'] = ((df['HighestSalary']+df['LowestSalary'])/2)
df.drop_duplicates() # Drop duplicate rows to minimize the number of rows.
# Out:
#               Id                                              Title  \
# 0       37404348                           Casual Stock Replenisher
# 1       37404337                           Casual Stock Replenisher
# 2       37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3       37404330                              Team member - Belrose
# 4       37404308  Business Banking Contact Centre Specialist, Ni...
# ...          ...                                                ...
# 318472  38564891                  Program Manager - Trade Reporting
# 318473  38564940            Web Content Writer - June 2019 contract
# 318474  38552964              Brand Director - Global Premium Brand
# 318475  38534438   Head of Financial Planning, Reporting & Strategy
# 318476  38561751                           Head of Operations - EOI
#
#                                                   Company  \
# 0                                             Aldi Stores
# ...

# %%
import re
# %matplotlib inline
# df1 = pd.read_csv("/content/drive/MyDrive/data.csv")
df['Id'] = df['Id'].replace(['+','*','%','_','#',',','¬','&','@'],'',regex=True).astype(int)
df

# %%
# df = pd.read_csv("data.csv")
df['Date'] = df['Date'].str.rstrip('T00:00:00.000Z')
df['Date']
# Out:
# 0         2018-10-07
# 1         2018-10-07
# 2         2018-10-07
# 3         2018-10-07
# 4         2018-10-07
#              ...
# 318472    2019-03-13
# 318473    2019-03-13
# 318474    2019-03-12
# 318475    2019-03-08
# 318476    2019-03-13
# Name: Date, Length: 318477, dtype: object

# %%
df.to_numeric(df['Id'] )

# %%
pd.to_datetime(df['Date'])
# Out:
# 0        2018-10-07
# 1        2018-10-07
# 2        2018-10-07
# 3        2018-10-07
# 4        2018-10-07
#             ...
# 318472   2019-03-13
# 318473   2019-03-13
# 318474   2019-03-12
# 318475   2019-03-08
# 318476   2019-03-13
# Name: Date, Length: 318477, dtype: datetime64[ns]

# %%
duplicatedRows = df.duplicated(['Id'])
duplicatedRows = duplicatedRows.value_counts()
duplicatedRows
# Out:
# False    318477
# dtype: int64

# %%
duplicatedRows = df.duplicated(['Title'])
duplicatedRows = duplicatedRows.value_counts()
duplicatedRows
# Out:
# False    168065
# True     150412
# dtype: int64

# %%
duplicates = df.drop_duplicates(['Title'])
duplicates.size
# Out:
# 2184845

# %%
df1 = pd.read_csv("/content/drive/MyDrive/data.csv")
duplicatedRows = df.duplicated(['Title'])
duplicatedRows
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 318472    False
# 318473    False
# 318474    False
# 318475     True
# 318476    False
# Length: 318477, dtype: bool

# %%
newdf = df.drop_duplicates(['Title'])
newdf
# Out:
#               Id                                              Title  \
# 0       37404348                           Casual Stock Replenisher
# 2       37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3       37404330                              Team member - Belrose
# 4       37404308  Business Banking Contact Centre Specialist, Ni...
# 6       37404355               Casual Café All-rounder in Semaphore
# ...          ...                                                ...
# 318470  38543176  General Manager, Transformation (PMO) c$270,00...
# 318472  38564891                  Program Manager - Trade Reporting
# 318473  38564940            Web Content Writer - June 2019 contract
# 318474  38552964              Brand Director - Global Premium Brand
# 318476  38561751                           Head of Operations - EOI
#
#                                                   Company  \
# 0                                             Aldi Stores
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/data.csv")
duplicate_count = df[df.duplicated()].shape[0]
print("Duplicates found: ", duplicate_count)
no_dates = df.drop('Date', axis=1)
duplicate_count_no_dates = no_dates[no_dates.duplicated()].shape[0]
difference = duplicate_count_no_dates - duplicate_count
print('Additional duplicates found without regard to timestamp: ', difference)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Duplicates found:  0
# Additional duplicates found without regard to timestamp:  0

# %% [markdown]
# ***Missing data and visualization***

# %%
df = pd.read_csv("/content/drive/MyDrive/data.csv")
nullFrame = df.isnull()
nullFrame
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            Id  Title  Company   Date  Location   Area  Classification  \
# 0       False  False    False  False     False  False           False
# 1       False  False    False  False     False   True           False
# 2       False  False    False  False     False  False           False
# 3       False  False    False  False     False   True           False
# 4       False  False    False  False     False  False           False
# ...       ...    ...      ...    ...       ...    ...             ...
# 318472  False  False    False  False      True   True            True
# 318473  False  False    False  False      True   True            True
# 318474  False  False    False  False      True   True            True
# ...

# %%
nullFrameMelted = nullFrame.melt(var_name='Attributes', value_name='Missing data vs existing')
nullCount = pd.crosstab(index=nullFrameMelted['Missing data vs existing'], columns=nullFrameMelted['Attributes'])
nullCount
# Out:
# Attributes                  Area  Classification  Company    Date  \
# Missing data vs existing
# False                     122658          197229   306473  318477
# True                      195819          121248    12004       0
#
# Attributes                FullDescription  HighestSalary      Id  JobType  \
# Missing data vs existing
# False                              302302         318477  318477   302379
# True                                16175              0       0    16098
#
# Attributes                Location  LowestSalary  Requirement  \
# Missing data vs existing
# False                       197229        318477       318470
# True                        121248             0            7
#
# Attributes                SubClassification   Title
# Missing data vs existing
# False                                197229  318477
# True                                 121248       0

# %%
def colorize_bar(value, max_value):
    low, high = max_value * 0.2, max_value * 0.66
    if(value <= low):
        return 'pink'
    elif(value >= high):
        return 'magenta'
    else:
        return 'hotpink'

df = pd.read_csv("/content/drive/MyDrive/data.csv")
nulls = df.isnull().sum()
cols = [colorize_bar(n, nulls.max()) for n in nulls]

total_data = [df.shape[0]] * df.shape[1]

plt.figure(figsize=(20,10))
plt.barh(df.columns.values,total_data, color='aliceblue')
plt.barh(df.columns.values,nulls, color=cols)

plt.ylabel('Attribute', size=14)
plt.xlabel('Missing data vs. existing', size=14)
plt.title('Missing data in dataset', size=20)
plt.savefig('my_plot.png')

plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # **Part 2: Data Analysis & Interpretation**

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd4

df = pd.read_csv("/content/drive/MyDrive/data.csv") # Jobmarket dataset.
df['Average_Salary'] = ((df['HighestSalary']+df['LowestSalary'])/2)
jobCount = df['Average_Salary'].value_counts()
jobCount.plot(kind='bar', 
                color=['BLUEVIOLET','DARKVIOLET',
                'DARKMAGENTA','PURPLE','INDIGO'], 
                title='Job distribution by average salary')
plt.savefig('average.png')

plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# df = pd.read_csv("data.csv") # Jobmarket dataset.
jobCounts = df['JobType'].value_counts()
jobCounts
# Out:
# Full Time          201225
# Contract/Temp       53906
# Casual/Vacation     25355
# Part Time           21893
# Name: JobType, dtype: int64

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv("data.csv") # Jobmarket dataset.
jobCounts = df['JobType'].value_counts()
jobCounts.plot(kind='pie',colors = ['LIME',
              'LIMEGREEN','SPRINGGREEN','GREEN','YELLOWGREEN',
              'OLIVE','GOLDENROD','CHOCOLATE','MAROON'],
        autopct = '%1.1f%%',title='Job posts by job type')
centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth =1.25)
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.savefig('jobs.png')

plt.show();

# %%
classes = df['Classification'].dropna().unique()
df_classification = pd.DataFrame({"Classification":classes})
df_classification['Count'] = df_classification['Classification'].apply(lambda x: len(df[df['Classification']==x]))
df_classification = df_classification.sort_values(by='Count', ascending=False)

# %%
import seaborn as sns
# Plot barplot
plt.figure(figsize=(8,8))
splot = sns.barplot(x=df_classification['Count'], y=df_classification['Classification'], palette='Spectral')
plt.title('\nNumber of Jobs by Classification\n',size=14)
plt.xlabel('Number of Jobs', fontsize=10)
plt.ylabel('Classification', fontsize=10)

#get the color of each classification to reuse later
color_by_classification = dict()
index = 0
for i, row in df_classification.iterrows():
    color_by_classification.update({row['Classification'] : splot.patches[index].get_facecolor()})
    index += 1
plt.savefig('job_classification')
plt.show()

# %%
pie_plt = df['Location'].value_counts()
piePlot = pie_plt.head(20)
piePlot
# Out:
# Sydney                                 60765
# Melbourne                              46690
# Brisbane                               21466
# Perth                                  13198
# Adelaide                                6653
# ACT                                     6250
# Newcastle, Maitland & Hunter            3958
# Gold Coast                              3588
# South West Coast VIC                    1790
# Mackay & Coalfields                     1701
# Port Hedland, Karratha & Pilbara        1667
# Wollongong, Illawarra & South Coast     1657
# Sunshine Coast                          1554
# Cairns & Far North                      1509
# Northern QLD                            1493
# Gosford & Central Coast                 1343
# Toowoomba & Darling Downs               1310
# Darwin                                  1266
# Hobart                                  1051
# Blue Mountains & Central West            942
# Name: Location, dtype: int64

# %%
df_classification= df.loc[df['Location'] == 'Brisbane']
# Pie char for job market share of classifications
df_classification = df_classification['Classification'].value_counts()
df_classification
# Out:
# Information & Communication Technology    2768
# Trades & Services                         1993
# Healthcare & Medical                      1824
# Manufacturing, Transport & Logistics      1667
# Hospitality & Tourism                     1335
# Education & Training                      1165
# Administration & Office Support           1107
# Accounting                                1064
# Engineering                                872
# Sales                                      857
# Construction                               844
# Retail & Consumer Products                 810
# Government & Defence                       800
# Legal                                      629
# Human Resources & Recruitment              461
# Community Services & Development           457
# Call Centre & Customer Service             446
# Mining, Resources & Energy                 442
# Real Estate & Property                     397
# Marketing & Communications                 347
# ...

# %%
colors = ['#6300BD','#8001DD','#A120F2','#C100FE','#DD00FD','#FF4FDB','#401F59','#61265F','#812D64','#A2346A','#C23B6F','#E34275']
df_classification.plot.pie(y='Classification', figsize=(10, 10),wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, colors=colors)
plt.title('Brisbane', fontsize = 40)
plt.savefig('brisbane')

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# df = pd.read_csv("data.csv") # Jobmarket dataset.
nf = df[['Location','HighestSalary']] # Creating new dataframe as nnf.
nf.groupby(['Location','HighestSalary']).mean() #Highest Average Salary.
nf.drop_duplicates()
nf.nlargest(30,'HighestSalary')
# Out:
#                                Location  HighestSalary
# 22979                            Sydney            999
# 22980                          Brisbane            999
# 22981                          Brisbane            999
# 22982   West Gippsland & Latrobe Valley            999
# 22983            Bairnsdale & Gippsland            999
# 22984                         Melbourne            999
# 22985                          Adelaide            999
# 22986                         Melbourne            999
# 22987                         Melbourne            999
# 22988                               ACT            999
# 22989                            Sydney            999
# 22990                            Sydney            999
# 22991                            Sydney            999
# 22992                            Sydney            999
# 22993                               ACT            999
# 22994                            Sydney            999
# ...

# %%
df_location = df[df['Location'].isna()==False]
df_top_30 = df_location.groupby(['Location']).count().reset_index().sort_values(by=['Title'],ascending=False)[:30]['Location'].tolist()
df_salary_locations_high = df[df['Location'].isin(df_top_30)]

plt.figure(figsize=(30,8))

box_plt_high = sns.boxplot(x='Location',y='HighestSalary',data=df_salary_locations_high, order=df_top_30,palette='flare')
box_plt_high.set_xticklabels(box_plt_high.get_xticklabels(),rotation=90,fontsize=20)
plt.title('Locations and the Average Highest Salary',size=30)
plt.ylabel('Highest Salary',fontsize=25)
plt.xlabel('Location',fontsize=25)

plt.ylim([0,250])
plt.savefig('location_avg_salary')
plt.show()

# %% [markdown]
# # **Part 3: Data Analysis and Visualization**

# %% [markdown]
# **1. Analyse by comparison**

# %%
# importing libraries
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(style="whitegrid") 

# loading dataset
df = pd.read_csv('/content/drive/MyDrive/data.csv')
df
# Out:
#               Id                                              Title  \
# 0       37404348                           Casual Stock Replenisher
# 1       37404337                           Casual Stock Replenisher
# 2       37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3       37404330                              Team member - Belrose
# 4       37404308  Business Banking Contact Centre Specialist, Ni...
# ...          ...                                                ...
# 318472  38564891                  Program Manager - Trade Reporting
# 318473  38564940            Web Content Writer - June 2019 contract
# 318474  38552964              Brand Director - Global Premium Brand
# 318475  38534438   Head of Financial Planning, Reporting & Strategy
# 318476  38561751                           Head of Operations - EOI
#
#                                                   Company  \
# 0                                             Aldi Stores
# ...

# %%
# Sydney and perth selected location
# jobs in sydney
print("Jobs in Sydney:")
grp = df.groupby('Location')
grp_sydney = grp.get_group('Sydney')
grp_sydney_job = grp_sydney.groupby('JobType')
sydney_total = grp_sydney_job['JobType'].count()
print(sydney_total)
# Out:
# Jobs in Sydney:
# JobType
# Casual/Vacation     3017
# Contract/Temp      10995
# Full Time          40607
# Part Time           2851
# Name: JobType, dtype: int64

# %%
# jobs in perth
print("\nJobs in Perth:")
grp = df.groupby('Location')
grp_perth = grp.get_group('Perth')
grp_perth_job = grp_perth.groupby('JobType')
perth_total = grp_perth_job['JobType'].count()
print(perth_total)
print("\nSydney has more jobs!")
# Out:
# Jobs in Perth:
# JobType
# Casual/Vacation    1157
# Contract/Temp      2544
# Full Time          7753
# Part Time           844
# Name: JobType, dtype: int64
#
# Sydney has more jobs!

# %%
# comparison between sydney and perth job sectors
grp_sydney = df[df['Location'] == "Sydney"]
grp = grp_sydney.groupby('Classification')
print("Top 5 job sectors in Sydney and their jobs:")
print(grp['Classification'].count().nlargest(5))

grp_perth = df[df['Location'] == "Perth"]
grp = grp_perth.groupby('Classification')
print("\nTop 5 job sectors in Perth and their jobs:")
print(grp['Classification'].count().nlargest(5))
# Out:
# Top 5 job sectors in Sydney and their jobs:
# Classification
# Information & Communication Technology    9548
# Hospitality & Tourism                     4074
# Trades & Services                         4026
# Accounting                                4010
# Healthcare & Medical                      3339
# Name: Classification, dtype: int64
#
# Top 5 job sectors in Perth and their jobs:
# Classification
# Trades & Services                         1520
# Mining, Resources & Energy                1428
# Information & Communication Technology    1137
# Healthcare & Medical                      1083
# Manufacturing, Transport & Logistics       799
# Name: Classification, dtype: int64

# %%
# pie charts for two locations
grp_sydney = df[df['Location'] == "Sydney"]
grp = grp_sydney.groupby('Classification')
print("Pie chart for Sydney:")
data = grp['Classification'].count().nlargest(5)
sydney_class = ['Information & Communication Technology','Trades & Services','Accounting','Hospitality & Tourism','Manufacturing, Transport & Logistics']
plt.pie(data, labels = sydney_class)
plt.savefig('sydney')
plt.title('Sydney', fontsize=40)
plt.show()
# Out:
# Pie chart for Sydney:

# %%
grp_perth = df[df['Location'] == "Perth"]
grp = grp_perth.groupby('Classification')
print("\nPie chart for Perth:")
data = grp['Classification'].count().nlargest(5)
perth_class = ['Trades & Services','Mining, Resources & Energy','Information & Communication Technology','Healthcare & Medical','Manufacturing, Transport & Logistics']
plt.pie(data, labels = perth_class)
plt.savefig('perth')
plt.title('Perth', fontsize=40)
plt.show()
# Out:
# Pie chart for Perth:

# %%
# perth salary range and jobs in each sector
grp_perth = df[df['Location'] == "Perth"]
grp = grp_perth.groupby('Classification')
print("Perth minimum and maximum salary noted in each sector:")
print(grp['LowestSalary','HighestSalary'].max())
print('\n Total jobs in sector')
print(grp['Classification'].count())
# Out:
# Perth minimum and maximum salary noted in each sector:
#                                         LowestSalary  HighestSalary
# Classification
# Accounting                                       200            999
# Administration & Office Support                  200            999
# Advertising, Arts & Media                        150            200
# Banking & Financial Services                     200            999
# CEO & General Management                         200            999
# Call Centre & Customer Service                   100            120
# Community Services & Development                 200            999
# Construction                                     200            999
# Consulting & Strategy                            200            999
# Design & Architecture                            150            200
# Education & Training                             200            999
# Engineering                                      200            999
# ...

# %%
# perth salary range and jobs in each sector
grp_perth = df[df['Location'] == "Sydney"]
grp = grp_perth.groupby('Classification')
print("Sydney minimum and maximum salary noted in each sector:")
print(grp['LowestSalary','HighestSalary'].max())
print('\n Total jobs in sector')
print(grp['Classification'].count())
# Out:
# Sydney minimum and maximum salary noted in each sector:
#                                         LowestSalary  HighestSalary
# Classification
# Accounting                                       200            999
# Administration & Office Support                  200            999
# Advertising, Arts & Media                        200            999
# Banking & Financial Services                     200            999
# CEO & General Management                         200            999
# Call Centre & Customer Service                   200            999
# Community Services & Development                 200            999
# Construction                                     200            999
# Consulting & Strategy                            200            999
# Design & Architecture                            200            999
# Education & Training                             200            999
# Engineering                                      200            999
# ...

# %%
# top 5 companies in sydney
grp_sydney = df[df['Location'] == "Sydney"]
grp = grp_sydney.groupby('Company')
data = grp['Company','Classification'].head(5)
data.head(5)
# Out:
#                                            Company  \
# 0                                      Aldi Stores
# 4   Commonwealth Bank - Business & Private Banking
# 5   Commonwealth Bank - Business & Private Banking
# 19                     Zoom Recruitment & Training
# 27                         National Australia Bank
#
#                           Classification
# 0             Retail & Consumer Products
# 4         Call Centre & Customer Service
# 5         Call Centre & Customer Service
# 19  Manufacturing, Transport & Logistics
# 27          Banking & Financial Services

# %%
# top 5 companies in perth
grp_perth = df[df['Location'] == "Perth"]
grp = grp_perth.groupby('Company')
data = grp['Company','Classification'].head(5)
data.head(5)
# Out:
#                                     Company                   Classification
# 12                         Mustard Catering            Hospitality & Tourism
# 33                     Black Force Security                Trades & Services
# 37                                 Advisian  Administration & Office Support
# 42  DoubleTree by Hilton, Perth Northbridge            Hospitality & Tourism
# 48                                      NaN       Retail & Consumer Products

# %%
# brisbane job sector analysis
grp_brisbane = df[df['Location'] == 'Brisbane']
grp_brisbane_comp = grp_brisbane.groupby('Company')
grp_brisbane_comp_res=grp_brisbane_comp['Classification','SubClassification','HighestSalary'].max()
print("Top 10 sectors and sub-sectors in Brisbane:")
grp_brisbane_comp_res.head(10)
# Out:
# Top 10 sectors and sub-sectors in Brisbane:
#                                                                     Classification  \
# Company
# 121 Care Inc                                      Community Services & Development
# 1300 Smoke Alarms Pty Ltd                          Administration & Office Support
# 1300SMILES Limited                                            Healthcare & Medical
# 1300hometutor                                                 Education & Training
# 13cabs                                             Administration & Office Support
# 19 Inns Chambers Pty Ltd                           Administration & Office Support
# 1iCT Pty Ltd                                                     Trades & Services
# 2 Sisters Gourmet Pty Ltd /Tastebuds Deli & Cafe             Hospitality & Tourism
# 21MT                                                    Mining, Resources & Energy
# 21st Century Boutique Properties                            Real Estate & Property
#
# ...

# %% [markdown]
# **2. Analyse by time**

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
df = pd.read_csv("/content/drive/MyDrive/data.csv") # Jobmarket dataset.
df["Date"] = df["Date"].replace(to_replace=r'T.*', value='', regex=True)
df["Date"] = pd.to_datetime(df["Date"])
df_monthly_counts = df[df["Date"].isna()==False]
df_monthly_counts["Month"] =  [x.strftime("%b") for x in df_monthly_counts["Date"]]

df_monthly_counts = df_monthly_counts.groupby('Month').count()
df_monthly_counts['Months'] = df_monthly_counts.index
df_monthly_counts['Number of Job Posts'] = df_monthly_counts["Id"]
#switch to sea born default
sns.set()
sns.barplot(x="Months", y="Number of Job Posts", data=df_monthly_counts)
plt.savefig('months')
plt.title("Job postings by the Months")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Job postings by the Months')

# %%
df["Date"] = df["Date"].replace(to_replace=r'T.*', value='', regex=True)
df["Date"] = pd.to_datetime(df["Date"])

#Create new column for day of week.
df['Day_of_Week'] = df["Date"].dt.day_name()
jobCountsbyDay = df['Day_of_Week'].value_counts()
jobCountsbyDay.plot(kind='bar', 
                color=['BLUEVIOLET','DARKVIOLET',
                'DARKMAGENTA','PURPLE','INDIGO'], 
                title='Job postings by the Days of Week')
plt.savefig('days')
plt.show()

# %%
plt.figure(figsize=(50,20))
df["Date"] = df["Date"].replace(to_replace=r'T.*', value='', regex=True)
df["Date"] = pd.to_datetime(df["Date"])
df_monthly_counts = df[df["Date"].isna()==False]
df_monthly_counts["DayOfMonth"] =  [x.strftime("%d") for x in df_monthly_counts["Date"]]

df_monthly_counts = df_monthly_counts.groupby('DayOfMonth').count()
df_monthly_counts['Day of Month'] = df_monthly_counts.index
df_monthly_counts['Number of Job Posts'] = df_monthly_counts["Id"]
#switch to sea born default
sns.set()
sns.barplot(x="Day of Month", y="Number of Job Posts", data=df_monthly_counts)
plt.title("Job postings by Day of Month", fontsize=30)
plt.savefig('tessstttyyy.png', dpi=100)
# plt.savefig('month.png')
plt.show()

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
df = pd.read_csv('/content/drive/MyDrive/data.csv') # Jobmarket dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_accounts = df[["Date","Location"]]
df_accounts
# Out:
#                             Date                 Location
# 0       2018-10-07T00:00:00.000Z                   Sydney
# 1       2018-10-07T00:00:00.000Z    Richmond & Hawkesbury
# 2       2018-10-07T00:00:00.000Z                 Brisbane
# 3       2018-10-07T00:00:00.000Z  Gosford & Central Coast
# 4       2018-10-07T00:00:00.000Z                   Sydney
# ...                          ...                      ...
# 318472  2019-03-13T00:00:00.000Z                      NaN
# 318473  2019-03-13T00:00:00.000Z                      NaN
# 318474  2019-03-12T00:00:00.000Z                      NaN
# 318475  2019-03-08T00:00:00.000Z                      NaN
# 318476  2019-03-13T00:00:00.000Z                      NaN
#
# [318477 rows x 2 columns]

# %%
ddf = pd.DataFrame()
nf = df_accounts[df_accounts["Location"]=="Sydney"]
ddf["Sydney"] = nf.groupby("Date").count()
ddf
# Out:
#                           Sydney
# Date
# 2018-10-01T00:00:00.000Z     320
# 2018-10-02T00:00:00.000Z     742
# 2018-10-03T00:00:00.000Z    1526
# 2018-10-04T00:00:00.000Z    2425
# 2018-10-05T00:00:00.000Z    1815
# ...                          ...
# 2018-12-12T00:00:00.000Z    2110
# 2018-12-13T00:00:00.000Z    2205
# 2018-12-14T00:00:00.000Z    3327
# 2018-12-15T00:00:00.000Z     422
# 2018-12-16T00:00:00.000Z     407
#
# [75 rows x 1 columns]

# %%
nf1 = df_accounts[df_accounts["Location"]=="Melbourne"]
ddf["Melbourne"] = nf1.groupby("Date").count()
nf2 = df_accounts[df_accounts["Location"]=="Brisbane"]
ddf["Brisbane"] = nf2.groupby("Date").count()
nf3 = df_accounts[df_accounts["Location"]=="Perth"]
ddf["Perth"] = nf3.groupby("Date").count()
nf4 = df_accounts[df_accounts["Location"]=="Adelaide"]
ddf["Adelaide"] = nf4.groupby("Date").count()
ddf
# Out:
#                           Sydney  Melbourne  Brisbane  Perth  Adelaide
# Date
# 2018-10-01T00:00:00.000Z     320        269      90.0   91.0      21.0
# 2018-10-02T00:00:00.000Z     742        449     174.0  120.0      47.0
# 2018-10-03T00:00:00.000Z    1526       1116     546.0  336.0     161.0
# 2018-10-04T00:00:00.000Z    2425       2047     973.0  564.0     315.0
# 2018-10-05T00:00:00.000Z    1815       1398     625.0  401.0     196.0
# ...                          ...        ...       ...    ...       ...
# 2018-12-12T00:00:00.000Z    2110       1659     664.0  477.0     233.0
# 2018-12-13T00:00:00.000Z    2205       2040     895.0  558.0     313.0
# 2018-12-14T00:00:00.000Z    3327       2648    1272.0  935.0     463.0
# 2018-12-15T00:00:00.000Z     422        239     112.0   32.0      39.0
# 2018-12-16T00:00:00.000Z     407        360     101.0   86.0      31.0
#
# [75 rows x 5 columns]

# %%
plt.figure(figsize=(50,20))
plt.plot(ddf,alpha=0.8, lw=2)
plt.legend(ddf[:5], title='Top 5 Cities', frameon=True)
plt.title('Job Posts by Location',size=25)
plt.xlabel('Date')
# plt.xticks(x)
plt.ylabel('Number of Job Posts')
plt.savefig('bigcity.png', dpi=100)
plt.show()

# %% [markdown]
# **3. Forecasting and skill extractions**

# %%
df = pd.read_csv('/content/drive/MyDrive/data.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#get dataframe with dates as index
df_timeseries_total = df.groupby(['Date']).count().reset_index().sort_values(by=['Date'])
df_timeseries_total.set_index('Date',inplace=True)

#exclude March because the dataset stops halfway through the month
df_timeseries_total = df_timeseries_total[:151]

# Get the count of jobs over time
df_timeseries_total = df_timeseries_total['Title'].rename('Count')

# Generate moving average over a weekly interval
moving_average_week = df_timeseries_total.rolling(7, min_periods=5)
moving_average_month = df_timeseries_total.rolling(30, min_periods=0)
plot_df = pd.DataFrame({'Count': df_timeseries_total, '7 Day Moving Average': moving_average_week.mean(), '30 Day Moving Average': moving_average_month.mean()})

plt.figure(figsize=(20,8))
plt.plot(plot_df['Count'],alpha=0.8, lw=2)
plt.plot(plot_df['7 Day Moving Average'],linestyle='--', lw=2)
plt.plot(plot_df['30 Day Moving Average'],linestyle='dotted', lw=3)
plt.legend(['Job Postings', '7 Day Moving Average', '30 Day Moving Average'], frameon=True)
plt.title('Job Posts Over Time',size=14)
plt.xlabel('Date')
plt.ylabel('Number of Job posts')
plt.savefig('time')
plt.show()

# %% [markdown]
# **2.**

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk.corpus import stopwords
import wordcloud

classifications = df['Classification'].dropna().unique()

custom_stopwords = ['store','join', 'looking', 'want', 'site', 'month', 'week', 'level', 'required', 'one', 'end', 'nsw',
                    'positions', 'make', 'across', 'take', 'key', 'large', 'based', 'melbourne', 'staff', 'australia',
                    'position', 'currently', 'full', 'projects', 'north', 'basis', 'next', '12', 'per', 'term', 'program',
                    'home', 'long' 'person', 'agency', 'apply', 'day', 'roles', 'within' 'perth', 'sydney',  'residential',
                    'years', '2019', 'market', 'data', 'exists', 'immediate', 'available', 'officer', 'needed', 'school',
                    'south', 'small', 'cbd', 'year', 'months', 'early', 'life', 'largest', '30', 'part', 'well', 'busy', 'cafe', 'restaurant']

stop_words = stopwords.words('english')
for word in custom_stopwords:
    stop_words.append(word)

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
def update(Classification="Information & Communication Technology"):
    requirements = df[df['Classification']==Classification]['Requirement'].dropna()
    original_documents = [x.strip() for x in requirements] 

    tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 1, stop_words = stop_words, max_features=200)

    features = tfidf.fit(original_documents)
    corpus_tf_idf = tfidf.transform(original_documents) 

    sum_words = corpus_tf_idf.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in tfidf.vocabulary_.items()]
    words_freq_dict = {x: y for x,y in words_freq}
    words_freq_dict.items()
    #print(sorted(words_freq, key = lambda x: x[1], reverse=True)[:5])

    word_cloud = wordcloud.WordCloud(width=1280,height=720,background_color='white',colormap='viridis')
    word_cloud.generate_from_frequencies(words_freq_dict)

    plt.figure(figsize=(16,16))
    plt.imshow(word_cloud,interpolation='bilinear')
    plt.axis("off")
    plt.title('TF-IDF Analysis of Requirements', size=14)
    plt.show()
    
interact(update, Classification=classifications)
# Out:
# interactive(children=(Dropdown(description='Classification', index=13, options=('Retail & Consumer Products', …
# <function __main__.update>

# %% [markdown]
# # **Part 4 - Discussion**

# %% [markdown]
# **Scenario 1**

# %%
df_classification= df.loc[df['Location'] == 'Brisbane']
# Pie char for job market share of classifications
# df_classification = df_classification['Classification'].value_counts()
df_classification = pd.DataFrame(df_classification)
df_classification
# Out:
#                                                        Id  \
# 2                                                37404356
# 7                                                37404350
# 21                                               37404239
# 26                                               37404396
# 40                                               37404400
# ...                                                   ...
# 197172  37829885&searchrequesttoken=9383958b-7a46-424e...
# 197174  37829862&searchrequesttoken=9383958b-7a46-424e...
# 197196  37828958&searchrequesttoken=8b903ecf-4f51-4a20...
# 197219  37828361&searchrequesttoken=5f3040c0-7469-48cc...
# 197228  37827864&searchrequesttoken=4e09ab58-a889-41f7...
#
#                                                     Title  \
# 2       RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 7                Casual Café All-rounder in Woolloongabba
# 21                             Casual Barista in Murarrie
# ...

# %%
df_Cls_count = df_classification['Classification'].value_counts()
df_Cls_count
# Out:
# Information & Communication Technology    2768
# Trades & Services                         1993
# Healthcare & Medical                      1824
# Manufacturing, Transport & Logistics      1667
# Hospitality & Tourism                     1335
# Education & Training                      1165
# Administration & Office Support           1107
# Accounting                                1064
# Engineering                                872
# Sales                                      857
# Construction                               844
# Retail & Consumer Products                 810
# Government & Defence                       800
# Legal                                      629
# Human Resources & Recruitment              461
# Community Services & Development           457
# Call Centre & Customer Service             446
# Mining, Resources & Energy                 442
# Real Estate & Property                     397
# Marketing & Communications                 347
# ...

# %%
df_subCls_count = df_classification['SubClassification'].value_counts()
df_subCls_count
# Out:
# Other                                  1247
# Management                              641
# Warehousing, Storage & Distribution     542
# Government - State                      538
# Administrative Assistants               531
#                                        ...
# Ambulance/Paramedics                      1
# Emergency Services                        1
# Fund Administration                       1
# Tax Law                                   1
# Corporate Development                     1
# Name: SubClassification, Length: 329, dtype: int64

# %%
it_df= df_classification.loc[df_classification['Classification'] == 'Information & Communication Technology']
grp = it_df.groupby('SubClassification')
grp_total = grp['SubClassification'].count()
grp_total.plot.pie()

# %%
new = it_df.loc[(it_df['LowestSalary'] > 80) & (df['HighestSalary'] > 80)]
new
# Out:
#                                                        Id  \
# 16554                                            37399005
# 16593                                            37398468
# 16676                                            37397595
# 16688                                            37397374
# 16724                                            37397057
# ...                                                   ...
# 197123  37831279&searchrequesttoken=c82fad91-0374-4dd6...
# 197170  37829936&searchrequesttoken=9383958b-7a46-424e...
# 197172  37829885&searchrequesttoken=9383958b-7a46-424e...
# 197174  37829862&searchrequesttoken=9383958b-7a46-424e...
# 197228  37827864&searchrequesttoken=4e09ab58-a889-41f7...
#
#                                                     Title  \
# 16554       Manager - Application Support (Legal Systems)
# 16593                         Principal Executive Officer
# 16676                         Front End Developer - React
# ...

# %%
new= new.loc[new['Classification'] == 'Information & Communication Technology']
grp1 = new.groupby('SubClassification')
grp_total1 = grp1['SubClassification'].count()
grp_total1
# Out:
# SubClassification
# Architects                               173
# Business/Systems Analysts                277
# Consultants                               84
# Database Development & Administration     55
# Developers/Programmers                   291
# Engineering - Hardware                     4
# Engineering - Network                     31
# Engineering - Software                    66
# Help Desk & IT Support                    11
# Management                                84
# Networks & Systems Administration         84
# Other                                     91
# Product Management & Development          16
# Programme & Project Management           319
# Sales - Pre & Post                        22
# Security                                  87
# Team Leaders                              14
# Technical Writing                         10
# Telecommunications                        12
# Testing & Quality Assurance              110
# ...

# %%
grp_total1.plot.pie()

# %% [markdown]
# **Extra Analysis**

# %%
df = pd.read_csv('/content/drive/MyDrive/data.csv')
df_classification= df.loc[df['Location'] == 'Brisbane']
# Pie char for job market share of classifications
# df_classification = df_classification['Classification'].value_counts()
df_classification = pd.DataFrame(df_classification)
df_classification
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                        Id  \
# 2                                                37404356
# 7                                                37404350
# 21                                               37404239
# 26                                               37404396
# 40                                               37404400
# ...                                                   ...
# 197172  37829885&searchrequesttoken=9383958b-7a46-424e...
# 197174  37829862&searchrequesttoken=9383958b-7a46-424e...
# 197196  37828958&searchrequesttoken=8b903ecf-4f51-4a20...
# 197219  37828361&searchrequesttoken=5f3040c0-7469-48cc...
# 197228  37827864&searchrequesttoken=4e09ab58-a889-41f7...
#
# ...

# %%
new1 = df_classification.loc[(df_classification['LowestSalary'] > 80) & (df_classification['HighestSalary'] > 80)]

# %%
grp1 = new1.groupby('SubClassification')
grp_total1 = grp1['SubClassification'].count()
grp_total1.sort_values()
# Out:
# SubClassification
# Sales - Outbound                       1
# Editing & Publishing                   1
# Client & Sales Administration          1
# Marketing Assistants/Coordinators      1
# Biotechnology & Genetics               1
#                                     ...
# Government - State                   285
# Developers/Programmers               291
# Programme & Project Management       319
# Management                           341
# Other                                351
# Name: SubClassification, Length: 254, dtype: int64

# %%
df = pd.read_csv('/content/drive/MyDrive/data.csv')
df_classification= df.loc[df['Location'] == 'Brisbane']
df_classification= df_classification.loc[df_classification['SubClassification'] == 'Management']
new1 = df_classification.loc[(df_classification['LowestSalary'] > 80) & (df_classification['HighestSalary'] > 80)]
new1
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                        Id  \
# 17183                                            37390422
# 17283                                            37389402
# 17297                                            37389277
# 17768                                            37384080
# 18059                                            37382095
# ...                                                   ...
# 196479  37852391&searchrequesttoken=6c899cac-f618-48eb...
# 196624  37847459&searchrequesttoken=c8c3452c-f1d0-49f1...
# 196668  37846193&searchrequesttoken=691693ba-5411-4178...
# 196698  37845583&searchrequesttoken=e095756a-4268-49bb...
# 196979  37836382&searchrequesttoken=72e6c917-0c99-4f62...
#
# ...

# %% [markdown]
# **Scenario 2**

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/data.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
job_counts = df['Classification'].value_counts()
job_counts
# Out:
# Information & Communication Technology    22796
# Trades & Services                         17976
# Healthcare & Medical                      17085
# Hospitality & Tourism                     15523
# Manufacturing, Transport & Logistics      12376
# Administration & Office Support           10020
# Accounting                                 9368
# Education & Training                       9280
# Construction                               8372
# Sales                                      8119
# Retail & Consumer Products                 8041
# Government & Defence                       7443
# Engineering                                6458
# Mining, Resources & Energy                 6288
# Banking & Financial Services               4633
# Community Services & Development           4485
# Legal                                      4237
# Human Resources & Recruitment              4144
# Call Centre & Customer Service             3971
# Marketing & Communications                 3968
# ...

# %%
job_sub_counts = df[df['Classification'] == 'Information & Communication Technology']
nnf = job_sub_counts['SubClassification'].value_counts()
nnf
# Out:
# Developers/Programmers                   4211
# Business/Systems Analysts                2986
# Programme & Project Management           2413
# Architects                               1548
# Engineering - Software                   1437
# Help Desk & IT Support                   1374
# Networks & Systems Administration        1194
# Consultants                              1149
# Other                                     997
# Testing & Quality Assurance               831
# Security                                  774
# Management                                746
# Engineering - Network                     552
# Database Development & Administration     551
# Web Development & Production              452
# Sales - Pre & Post                        449
# Product Management & Development          376
# Telecommunications                        357
# Team Leaders                              173
# Engineering - Hardware                    116
# ...

# %%
job_sub_counts = df[df['Classification'] == 'Trades & Services']
nnf = job_sub_counts['SubClassification'].value_counts()
nnf
# Out:
# Automotive Trades                     3262
# Electricians                          1783
# Labourers                             1536
# Fitters, Turners & Machinists         1334
# Technicians                           1161
# Welders & Boilermakers                1155
# Carpentry & Cabinet Making             977
# Hair & Beauty Services                 976
# Other                                  909
# Gardening & Landscaping                828
# Cleaning Services                      620
# Air Conditioning & Refrigeration       570
# Plumbers                               567
# Building Trades                        544
# Security Services                      483
# Maintenance & Handyperson Services     470
# Painters & Sign Writers                262
# Bakers & Pastry Chefs                  176
# Printing & Publishing Services         154
# Butchers                               102
# Tailors & Dressmakers                   35
# Locksmiths                              29
# ...

# %%
job_sub_counts = df[df['Classification'] == 'Healthcare & Medical']
nnf = job_sub_counts['SubClassification'].value_counts()
nnf
# Out:
# Nursing - Aged Care                                2130
# Physiotherapy, OT & Rehabilitation                 1821
# General Practitioners                              1263
# Psychology, Counselling & Social Work              1123
# Nursing - General Medical & Surgical               1066
# Dental                                             1046
# Other                                               829
# Medical Administration                              812
# Pharmacy                                            808
# Medical Specialists                                 748
# Pharmaceuticals & Medical Devices                   502
# Management                                          496
# Medical Imaging                                     487
# Nursing - A&E, Critical Care & ICU                  446
# Nursing - Psych, Forensic & Correctional Health     433
# Nursing - Management                                374
# Sales                                               347
# ...
