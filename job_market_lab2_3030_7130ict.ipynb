# %% [markdown]
# <a href="https://colab.research.google.com/github/singithi03/Data-Analytics_s5214680/blob/Lab-2/job_market_lab2_3030_7130ict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
jobs = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/7130 Data Analytics/Lab 2/job-market(3).csv")
jobs.head(3)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
#
#                Company                      Date               Location  \
# 0          Aldi Stores  2018-10-07T00:00:00.000Z                 Sydney
# 1          Aldi Stores  2018-10-07T00:00:00.000Z  Richmond & Hawkesbury
# 2  LB Creative Pty Ltd  2018-10-07T00:00:00.000Z               Brisbane
#
#                           Area              Classification  SubClassification  \
# 0  North West & Hills District  Retail & Consumer Products  Retail Assistants
# 1                          NaN  Retail & Consumer Products  Retail Assistants
# 2          CBD & Inner Suburbs  Retail & Consumer Products  Retail Assistants
#
#                                          Requirement FullDescription  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline

sns.countplot(y = 'Location', data=jobs)
order = jobs['Location'].value_counts().index

# %%
import matplotlib
#Load job market
jobs = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/7130 Data Analytics/Lab 2/job-market(3).csv")
#create dataframe for salary ranges
df = jobs.groupby(["LowestSalary", "HighestSalary"])
df.first()
# Out:
#                                     Id  \
# LowestSalary HighestSalary
# 0.0          30.0           37404348.0
# 30.0         40.0           37400094.0
# 40.0         50.0           37403460.0
# 50.0         60.0           37404404.0
#
#                                                                   Title  \
# LowestSalary HighestSalary
# 0.0          30.0                              Casual Stock Replenisher
# 30.0         40.0                                      Tele Sales Role.
# 40.0         50.0                                       MOTOR MECHANIC
# 50.0         60.0           Qualified HAIRDRESSER & 1st Year Apprentice
#
#                                        Company                      Date  \
# LowestSalary HighestSalary
# 0.0          30.0                  Aldi Stores  2018-10-07T00:00:00.000Z
# 30.0         40.0           Plumboss Australia  2018-10-05T00:00:00.000Z
# 40.0         50.0                    Eldercare  2018-10-07T00:00:00.000Z
# ...

# %%
#salary ranges plot
import matplotlib.pyplot as plt
import numpy as np


#Load job market
jobs = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/7130 Data Analytics/Lab 2/job-market(3).csv")
#create dataframe for salary ranges
df = jobs.groupby(["LowestSalary", "HighestSalary"])
plt.pie(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-afe41375214f> in <module>()
#       8 #create dataframe for salary ranges
#       9 df = jobs.groupby(["LowestSalary", "HighestSalary"])
# ---> 10 plt.pie(df)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
#OPTIONAL

locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf['Count'] = locationDf["Id"]
locationDf.head()
# Out:
#                            Id  Title  Company  Date  Area  Classification  \
# Location
# ACT                       238    238      235   238     0             238
# Adelaide                  390    390      356   390     0             390
# Adelaide Hills & Barossa   19     19       18    19     0              19
# Albany & Great Southern    10     10       10    10     0              10
# Albury Area                19     19       18    19     0              19
#
#                           SubClassification  Requirement  FullDescription  \
# Location
# ACT                                     238          238              235
# Adelaide                                390          390              374
# Adelaide Hills & Barossa                 19           19               19
# Albany & Great Southern                  10           10               10
# Albury Area                              19           19               19
#
# ...

# %%
#OPTIONAL

# %matplotlib inline
# Pie char for job market share of cities
from matplotlib import cm
# Out:
# Text(50.0, 0.5, '')
